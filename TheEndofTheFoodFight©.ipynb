# %%
print('Hello! Welcome to the End of the Food Fight©!')
Anwser=input('Do you need a place to eat?(Anwser Yes or No)')
CustomPref=[]
if Anwser=='No':
  print('Damn. im gonna help you either way')
else:
  print('Dont worry! I gotchu!')
Budget=input("What's your budget per person(in $)?")
CustomPref.append(Budget)
Cuisine=input("What cuisine of food?(American, Chinese, Thai, Japanese, Mexican, Italian)")
CustomPref.append(Cuisine)
Size=input('Are you looking for a meal or a snack?')
CustomPref.append(Size)
#Customer Preferences and basic intro

#Data lists for all restaurants below
Chinese_Meal_LowCost=['Panda Express','ChinaTown','Wing Hing']
Chinese_Meal_MedCost=['Kung Fu Noodle House','Wongs Garden']
Chinese_Meal_HighCost=['PF Changs','China Chef','Mon Jin Lau']
American_Meal_LowCost=['Wendys','McDonalds','Burger King','Big Boy']
American_Meal_MedCost=['Romiras City Grill','The Gathering Place']
American_Meal_HighCost=['Granite City','Yard House','Sedona Taphouse','Kona Grill']
Mexican_Meal_LowCost=['Taco Bell','Condado Tacos','Qdoba','Chipotle']
Mexican_Meal_MedCost=['Oaxaca Mexican Grill','Detroit Taco Company','Azteca','La Botana']
Mexican_Meal_HighCost=['Gran Castor','Pancho Villas','Las Tortugas Taqueria']
Japanese_Meal_LowCost=['Wow Sushi','Kroger lol']
Japanese_Meal_MedCost=['Noble Fish','Sapporo Sushi','Kazoku Sushi']
Japanese_Meal_HighCost=['Benihana','Cafe Sushi','Tomo Sushi and Karaoke']
Italian_Meal_LowCost=['Benitos','Papa Romanos','Toarminas','MOD Pizza']
Italian_Meal_MedCost=['Olive Garden','Apovini Grill']
Italian_Meal_HighCost=['Maggianos Little Italy','Carrabas Itlaian Grill','Loccino','Picanos']
Thai_Meal_LowCost=['Thai Taste to Go','Troy Orchid Cafe']
Thai_Meal_MedCost=['Sythai','Flaming Hot Thai Cafe,','Troy Orchid Cafe']
Thai_Meal_HighCost=['Bangkok Cuisine','Lemon Grass','Mon Jin Lau']
#End of Data List for Now

#Start of Determining Customer Final options
print('There are a few options within a budget of $'+str(Budget)+' in the '+Cuisine+' cuisine in Troy, MI.')
print('-------------------------------------------------------------------------------------------------------------------')
Budget1=5
LowRange=range(0,11)
MedRange=range(11,25)
HighRange=range(25,100)
if Budget in LowRange:
  Budget1=Budget1-1
elif Budget in MedRange:
  Budget1=Budget1-2
else:
  Budget1=Budget1-3

if Cuisine=='American' and Budget1==2:
  print('Try these restauraunts: '+str(American_Meal_HighCost))
elif Cuisine=='American' and Budget1==3:
  print('Try these restauraunts: '+str(American_Meal_MedCost))
elif Cuisine=='American' and Budget1==4:
  print('Try these restauraunts: '+str(American_Meal_LowCost))
elif Cuisine=='Italian' and Budget1==2:
  print('Try these restauraunts: '+str(Italian_Meal_HighCost))
elif Cuisine=='Italian' and Budget1==3:
  print('Try these restauraunts: '+str(Italian_Meal_MedCost))
elif Cuisine=='Italian' and Budget1==4:
  print('Try these restauraunts: '+str(Italian_Meal_LowCost))
elif Cuisine=='Chinese' and Budget1==2:
  print('Try these restauraunts: '+str(Chinese_Meal_HighCost))
elif Cuisine=='Chinese' and Budget1==3:
  print('Try these restauraunts: '+str(Chinese_Meal_MedCost))
elif Cuisine=='Chinese' and Budget1==4:
  print('Try these restauraunts: '+str(Chinese_Meal_LowCost))
elif Cuisine=='Mexican' and Budget1==2:
  print('Try these restauraunts: '+str(Mexican_Meal_HighCost))
elif Cuisine=='Mexican' and Budget1==3:
  print('Try these restauraunts: '+str(Mexican_Meal_MedCost))
elif Cuisine=='Mexican' and Budget1==4:
  print('Try these restauraunts: '+str(Mexican_Meal_LowCost))
elif Cuisine=='Japanese' and Budget1==2:
  print('Try these restauraunts: '+str(Japanese_Meal_HighCost))
elif Cuisine=='Japanese' and Budget1==3:
  print('Try these restauraunts: '+str(Japanese_Meal_MedCost))
elif Cuisine=='Japanese' and Budget1==4:
  print('Try these restauraunts: '+str(Japanese_Meal_LowCost))
elif Cuisine=='Thai' and Budget1==2:
  print('Try these restauraunts: '+str(Thai_Meal_HighCost))
elif Cuisine=='Thai' and Budget1==3:
  print('Try these restauraunts: '+str(Thai_Meal_MedCost))
elif Cuisine=='Thai' and Budget1==4:
  print('Try these restauraunts: '+str(Thai_Meal_LowCost))
else:
  print('Please make sure you chose one of the available options without any spelling errors!')
  exit()
print('-------------------------------------------------------------------------------------------------------------------')
print('Bon appetit! More options and data will come as I learn how to do this!')
# Out:
# Hello! Welcome to the food decision maker!
# Do you need a place to eat?(Anwser Yes or No)Yes
# Dont worry! I gotchu!
# What's your budget per person(in $)?25
# What cuisine of food?(American, Chinese, Thai, Japanese, Mexican, Italian)Thai
# Are you looking for a meal or a snack?meal
# There are a few options within a budget of $25 in the Thai cuisine in Troy, MI.
# -------------------------------------------------------------------------------------------------------------------
# Try these restauraunts: ['Bangkok Cuisine', 'Lemon Grass', 'Mon Jin Lau']
# -------------------------------------------------------------------------------------------------------------------
# Bon appetit! More options and data will come as I learn how to do this!
